# %%
import pandas as pd

df= pd.read_csv("ai_student_impact_dataset.csv")

print(df.describe())

# check Perceived_AI_Dependency,Institutional_Policy,Anxiety_Level_During_Exams

print(df["Perceived_AI_Dependency"].value_counts())
print(df["Institutional_Policy"].value_counts())    
print(df["Anxiety_Level_During_Exams"].value_counts())  
df.corr(numeric_only=True)
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   50000.000000      50000.000000        50000.000000     50000.00000
# mean   125000.500000          3.146102            8.427752         2.80026
# std     14433.901067          0.478854            8.269490         1.18802
# min    100001.000000          1.183000            0.000000         1.00000
# 25%    112500.750000          2.834000            2.390000         2.00000
# 50%    125000.500000          3.210000            5.800000         3.00000
# 75%    137500.250000          3.521000           11.720000         4.00000
# max    150000.000000          3.998000           40.000000         5.00000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             50000.000000             50000.000000
# mean                 11.209271                 3.505360
# std                   5.156426                 1.820812
# min                   1.000000                 1.000000
# 25%                   7.560000                 2.000000
# 50%                  11.180000                 3.000000
# 75%                  14.710000                 5.000000
# max                  35.860000                10.000000
#
#        Anxiety_Level_During_Exams  Post_Semester_GPA  Skill_Retention_Score
# count                50000.000000       50000.000000           50000.000000
# mean                     4.270760           3.349299              75.798125
# std                      2.144066           0.495673              13.281626
# min                      1.000000           1.000000              10.780000
# 25%                      3.000000           3.023750              66.820000
# 50%                      4.000000           3.421000              76.000000
# 75%                      6.000000           3.749000              85.190000
# max                     10.000000           4.000000             100.000000
# Perceived_AI_Dependency
# 3     10478
# 4      9934
# 2      8874
# 1      7303
# 5      6745
# 6      3521
# 7      1722
# 8       855
# 9       378
# 10      190
# Name: count, dtype: int64
# Institutional_Policy
# Allowed_With_Citation    25224
# Actively_Encouraged      14988
# Strict_Ban                9788
# Name: count, dtype: int64
# Anxiety_Level_During_Exams
# 4     8749
# 5     8222
# 3     7806
# 6     6107
# 2     5752
# 1     5655
# 7     3850
# 8     2088
# 9     1151
# 10     620
# Name: count, dtype: int64
#                             Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# Student_ID                    1.000000          0.002275            0.001577
# Pre_Semester_GPA              0.002275          1.000000           -0.001084
# Weekly_GenAI_Hours            0.001577         -0.001084            1.000000
# Tool_Diversity               -0.001187         -0.005671            0.008411
# Paid_Subscription            -0.000319         -0.001027            0.196943
# Traditional_Study_Hours       0.000648         -0.004620           -0.157368
# Perceived_AI_Dependency       0.002768          0.000701            0.665479
# Anxiety_Level_During_Exams    0.009670         -0.000667            0.269080
# Post_Semester_GPA            -0.000602          0.926781           -0.018600
# Skill_Retention_Score        -0.001737          0.099019           -0.118099
#
#                             Tool_Diversity  Paid_Subscription  \
# Student_ID                       -0.001187          -0.000319
# Pre_Semester_GPA                 -0.005671          -0.001027
# Weekly_GenAI_Hours                0.008411           0.196943
# Tool_Diversity                    1.000000           0.005803
# Paid_Subscription                 0.005803           1.000000
# Traditional_Study_Hours           0.003565          -0.035329
# Perceived_AI_Dependency           0.006019           0.131033
# Anxiety_Level_During_Exams        0.003189           0.065845
# Post_Semester_GPA                 0.025265           0.005528
# Skill_Retention_Score             0.196952          -0.024083
#
#                             Traditional_Study_Hours  Perceived_AI_Dependency  \
# Student_ID                                 0.000648                 0.002768
# Pre_Semester_GPA                          -0.004620                 0.000701
# Weekly_GenAI_Hours                        -0.157368                 0.665479
# Tool_Diversity                             0.003565                 0.006019
# Paid_Subscription                         -0.035329                 0.131033
# Traditional_Study_Hours                    1.000000                -0.102625
# Perceived_AI_Dependency                   -0.102625                 1.000000
# Anxiety_Level_During_Exams                -0.040935                 0.307620
# Post_Semester_GPA                          0.137653                -0.014180
# Skill_Retention_Score                      0.147565                -0.084324
#
#                             Anxiety_Level_During_Exams  Post_Semester_GPA  \
# Student_ID                                    0.009670          -0.000602
# Pre_Semester_GPA                             -0.000667           0.926781
# Weekly_GenAI_Hours                            0.269080          -0.018600
# Tool_Diversity                                0.003189           0.025265
# Paid_Subscription                             0.065845           0.005528
# Traditional_Study_Hours                      -0.040935           0.137653
# Perceived_AI_Dependency                       0.307620          -0.014180
# Anxiety_Level_During_Exams                    1.000000          -0.015909
# Post_Semester_GPA                            -0.015909           1.000000
# Skill_Retention_Score                        -0.041556           0.169616
#
#                             Skill_Retention_Score
# Student_ID                              -0.001737
# Pre_Semester_GPA                         0.099019
# Weekly_GenAI_Hours                      -0.118099
# Tool_Diversity                           0.196952
# Paid_Subscription                       -0.024083
# Traditional_Study_Hours                  0.147565
# Perceived_AI_Dependency                 -0.084324
# Anxiety_Level_During_Exams              -0.041556
# Post_Semester_GPA                        0.169616
# Skill_Retention_Score                    1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  str
#  2   Year_of_Study               50000 non-null  str
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  str
#  6   Prompt_Engineering_Skill    50000 non-null  str
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  str
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
#  13  Post_Semester_GPA           50000 non-null  float64
#  14  Skill_Retention_Score       50000 non-null  float64
#  15  Burnout_Risk_Level          50000 non-null  str
# dtypes: bool(1), float64(5), int64(4), str(6)
# memory usage: 5.8 MB

# %%
df["GPA_increment"]= df["Post_Semester_GPA"] - df["Pre_Semester_GPA"]

df.corr(numeric_only=True)
# Out:
#                             Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# Student_ID                    1.000000          0.002275            0.001577
# Pre_Semester_GPA              0.002275          1.000000           -0.001084
# Weekly_GenAI_Hours            0.001577         -0.001084            1.000000
# Tool_Diversity               -0.001187         -0.005671            0.008411
# Paid_Subscription            -0.000319         -0.001027            0.196943
# Traditional_Study_Hours       0.000648         -0.004620           -0.157368
# Perceived_AI_Dependency       0.002768          0.000701            0.665479
# Anxiety_Level_During_Exams    0.009670         -0.000667            0.269080
# Post_Semester_GPA            -0.000602          0.926781           -0.018600
# Skill_Retention_Score        -0.001737          0.099019           -0.118099
# GPA_increment                -0.007413         -0.104035           -0.046479
#
#                             Tool_Diversity  Paid_Subscription  \
# Student_ID                       -0.001187          -0.000319
# Pre_Semester_GPA                 -0.005671          -0.001027
# Weekly_GenAI_Hours                0.008411           0.196943
# Tool_Diversity                    1.000000           0.005803
# Paid_Subscription                 0.005803           1.000000
# Traditional_Study_Hours           0.003565          -0.035329
# Perceived_AI_Dependency           0.006019           0.131033
# Anxiety_Level_During_Exams        0.003189           0.065845
# Post_Semester_GPA                 0.025265           0.005528
# Skill_Retention_Score             0.196952          -0.024083
# GPA_increment                     0.081407           0.017265
#
#                             Traditional_Study_Hours  Perceived_AI_Dependency  \
# Student_ID                                 0.000648                 0.002768
# Pre_Semester_GPA                          -0.004620                 0.000701
# Weekly_GenAI_Hours                        -0.157368                 0.665479
# Tool_Diversity                             0.003565                 0.006019
# Paid_Subscription                         -0.035329                 0.131033
# Traditional_Study_Hours                    1.000000                -0.102625
# Perceived_AI_Dependency                   -0.102625                 1.000000
# Anxiety_Level_During_Exams                -0.040935                 0.307620
# Post_Semester_GPA                          0.137653                -0.014180
# Skill_Retention_Score                      0.147565                -0.084324
# GPA_increment                              0.376317                -0.039342
#
#                             Anxiety_Level_During_Exams  Post_Semester_GPA  \
# Student_ID                                    0.009670          -0.000602
# Pre_Semester_GPA                             -0.000667           0.926781
# Weekly_GenAI_Hours                            0.269080          -0.018600
# Tool_Diversity                                0.003189           0.025265
# Paid_Subscription                             0.065845           0.005528
# Traditional_Study_Hours                      -0.040935           0.137653
# Perceived_AI_Dependency                       0.307620          -0.014180
# Anxiety_Level_During_Exams                    1.000000          -0.015909
# Post_Semester_GPA                            -0.015909           1.000000
# Skill_Retention_Score                        -0.041556           0.169616
# GPA_increment                                -0.040420           0.277146
#
#                             Skill_Retention_Score  GPA_increment
# Student_ID                              -0.001737      -0.007413
# Pre_Semester_GPA                         0.099019      -0.104035
# Weekly_GenAI_Hours                      -0.118099      -0.046479
# Tool_Diversity                           0.196952       0.081407
# Paid_Subscription                       -0.024083       0.017265
# Traditional_Study_Hours                  0.147565       0.376317
# Perceived_AI_Dependency                 -0.084324      -0.039342
# Anxiety_Level_During_Exams              -0.041556      -0.040420
# Post_Semester_GPA                        0.169616       0.277146
# Skill_Retention_Score                    1.000000       0.195833
# GPA_increment                            0.195833       1.000000

# %%
df=df[["GPA_increment","Weekly_GenAI_Hours","Traditional_Study_Hours"]]
df["study_group"]=pd.cut(df["Traditional_Study_Hours"],[0,5,10,15,20,25,30,35,float("inf")])
sns.scatterplot(data=df,x="Weekly_GenAI_Hours",y="GPA_increment",hue="study_group",palette='rocket')

plt.plot()
# Out:
# []

# %%
df.corr(numeric_only=True)
# Out:
#                          GPA_increment  Weekly_GenAI_Hours  \
# GPA_increment                 1.000000           -0.046479
# Weekly_GenAI_Hours           -0.046479            1.000000
# Traditional_Study_Hours       0.376317           -0.157368
#
#                          Traditional_Study_Hours
# GPA_increment                           0.376317
# Weekly_GenAI_Hours                     -0.157368
# Traditional_Study_Hours                 1.000000

# %% [markdown]
# Si può osservare come il GPA increment dipenda principalmente dalle ore di studio tradizional, l'uso di GenAI invece e leggermente inversamente correlato alle ore di studio tradizionali.
# Inoltre da grafo notiamo che con aumento di ore di GenAI aumenta il rischio di avre decremento maggiore di GPA

# %%
df["AI_usage_groups"]= pd.cut(df["Weekly_GenAI_Hours"], bins=[-1, 0, 5, 10,15,20,25,30,35,40, float('inf')], labels=["0", "1-5", "6-10", "11-15", "16-20", "21-25", "26-30", "31-35", "36-40", "40+"])
plt.yticks(rotation=90)
sns.barplot(data=df,x="AI_usage_groups",y="GPA_increment")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x="Weekly_GenAI_Hours",y="Traditional_Study_Hours",hue="GPA_increment",palette="rocket")

plt.plot()
# Out:
# []

# %%
df["trad_prop"]=df["Traditional_Study_Hours"]/(df["Weekly_GenAI_Hours"]+df["Traditional_Study_Hours"])

df["tot_study"]=df["Weekly_GenAI_Hours"]+df["Traditional_Study_Hours"]

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x="trad_prop",y ="tot_study",hue="GPA_increment", palette="rocket")

plt.plot()
# Out:
# []

# %% [markdown]
# chiaro = meglio
